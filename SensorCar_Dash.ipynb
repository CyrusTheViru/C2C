# %% [markdown]
# # Projektphase 1

# %% [markdown]
# ## Lastenheft Aufgabe 10

# %% [markdown]
# ### Dash Stufe 1

# %%
from jupyter_dash import JupyterDash
from dash import dcc
from dash import html
import pandas as pd
import numpy as np
import plotly.express as px
from dash.dependencies import Input, Output
import dash_bootstrap_components as dbc
import datetime

df = pd.read_csv('Log_SensorCar_USS_n.csv')

app = JupyterDash()

speed_max = df['Geschwindigkeit'].max()
speed_min = df['Geschwindigkeit'].min()
speed_mean = df['Geschwindigkeit'].mean()
speed_mean = np.round(speed_mean, decimals = 2)


distance = 0
time = 0
time_sum = 0
df.insert(5,'Gefahrene_Zeit', True)
df.insert(6,'Gefahrene_Distanz', True)

for i in df['Geschwindigkeit']:
    
    if i <= 2:
        df['Gefahrene_Zeit'][i] = 0
    else:
        time_1 = df['Zeit'][i-1]
        time_1 = datetime.datetime.strptime(time_1, '%H:%M:%S.%f')

        time_2 = df['Zeit'][i]
        time_2 = datetime.datetime.strptime(time_2, '%H:%M:%S.%f')

        time = time_2 - time_1
        time = time.total_seconds()
        
    speed = df['Geschwindigkeit'][i]
    distance = distance + (time*speed/1000)
    time_sum = time_sum + (time/1000)
    
    df['Gefahrene_Zeit'][i] = time_sum
    df['Gefahrene_Distanz'][i] = distance

distance = np.round(distance, decimals = 2)
time_sum = np.round(time_sum, decimals = 2)

app = JupyterDash(external_stylesheets=[dbc.themes.BOOTSTRAP])


speed_max_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Maximale Geschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_max, body=True),
    ]
)

speed_min_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Minimale Geschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_min, body=True),
    ]
)

speed_mean_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Durchschnittsgeschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_mean, body=True),
        
    ]
)

distance_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Gefahrene Distanz"),
            className="card-text",
        ),
        dbc.Card(distance, body=True),
    ]
)

time_sum_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Gefahrene Zeit"),
            className="card-text",
        ),
        dbc.Card(time_sum, body=True),
    ]
)


app.layout = html.Div(
    children=[
        html.H1(id='H1',
                children='Auswertung des Log-Files',
                style={'textAlign': 'center', 'marginTop': 40, 'marginBottom': 40}),
        html.H1(id='H2',
                children='Log_SensorCar_USS.csv'),
        html.Br(),
        dbc.Row([
            dbc.Col([speed_max_card], width=2),
            dbc.Col([speed_min_card], width=2),
            dbc.Col([speed_mean_card], width=2),
            dbc.Col([distance_card], width=2),
            dbc.Col([time_sum_card], width=2),
        ], align='center'),
    ]
)

app.layout = html.Div(
    children=[
        html.H1(id='H1',
                children='Übersicht Pi Car',
                style={'textAlign': 'center', 'marginTop': 40, 'marginBottom': 40}),
        html.H1(id='H2',
                children='DasH'),
        html.Div(children='Ein ganz normaler Container (div) für Fließende Objekte'),
        #dcc.Dropdown(id='dropdown',
                     #options=[
                     #    {'label': 'Geschwindigkeit', 'value': 'Geschwindigkeit'},
                     #    {'label': 'Fahrtrichtung', 'value': 'Fahrtrichtung'},
                     #    {'label': 'Lenkwinkel', 'value': 'Lenkwinkel'},
                     #    {'label': 'Abstand_Hindernis', 'value': 'Abstand_Hindernis'},
                     #],
                     #value='Geschwindigkeit'),
         dcc.Graph(id='line_plot', figure=px.line(
            df, x=df['Zeit'], y=df['Geschwindigkeit'])),
        #dcc.Graph(id='line_plot'),
        html.Br(),
        dbc.Row([
            dbc.Col([speed_max_card]),
            dbc.Col([speed_min_card]),
            dbc.Col([speed_mean_card]),
            dbc.Col([distance_card]),
            dbc.Col([time_sum_card]),
        ], align='center'),
    ]
)


@app.callback(Output(component_id='line_plot', component_property='figure'),
              [Input(component_id='dropdown', component_property='value')])
def graph_update(value_of_input_component):
    print(value_of_input_component)
    fig = px.line(df, x=df["Zeit"], y=df[value_of_input_component])
    return fig


if __name__ == '__main__':
    app.run_server(port=8052)
# Out:
# <ipython-input-8-49161b44672e>:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-8-49161b44672e>:45: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-8-49161b44672e>:46: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Dash app running on http://127.0.0.1:8052/

# %% [markdown]
# ### Dash Stufe 2

# %%
from jupyter_dash import JupyterDash
from dash import dcc
from dash import html
import pandas as pd
import numpy as np
import plotly.express as px
from dash.dependencies import Input, Output
import dash_bootstrap_components as dbc
import datetime

df = pd.read_csv('Log_SensorCar_USS_n.csv')

app = JupyterDash()

speed_max = df['Geschwindigkeit'].max()
speed_min = df['Geschwindigkeit'].min()
speed_mean = df['Geschwindigkeit'].mean()
speed_mean = np.round(speed_mean, decimals = 2)


distance = 0
time = 0
time_sum = 0
df.insert(5,'Gefahrene_Zeit', True)
df.insert(6,'Gefahrene_Distanz', True)

for i in df['Geschwindigkeit']:
    
    if i <= 2:
        df['Gefahrene_Zeit'][i] = 0
    else:
        time_1 = df['Zeit'][i-1]
        time_1 = datetime.datetime.strptime(time_1, '%H:%M:%S.%f')

        time_2 = df['Zeit'][i]
        time_2 = datetime.datetime.strptime(time_2, '%H:%M:%S.%f')

        time = time_2 - time_1
        time = time.total_seconds()
        
    speed = df['Geschwindigkeit'][i]
    distance = distance + (time*speed/1000)
    time_sum = time_sum + (time/1000)
    
    df['Gefahrene_Zeit'][i] = time_sum
    df['Gefahrene_Distanz'][i] = distance

distance = np.round(distance, decimals = 2)
time_sum = np.round(time_sum, decimals = 2)

app = JupyterDash(external_stylesheets=[dbc.themes.BOOTSTRAP])


speed_max_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Maximale Geschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_max, body=True),
    ]
)

speed_min_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Minimale Geschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_min, body=True),
    ]
)

speed_mean_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Durchschnittsgeschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_mean, body=True),
        
    ]
)

distance_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Gefahrene Distanz"),
            className="card-text",
        ),
        dbc.Card(distance, body=True),
    ]
)

time_sum_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Gefahrene Zeit"),
            className="card-text",
        ),
        dbc.Card(time_sum, body=True),
    ]
)


app.layout = html.Div(
    children=[
        html.H1(id='H1',
                children='Auswertung des Log-Files',
                style={'textAlign': 'center', 'marginTop': 40, 'marginBottom': 40}),
        html.H1(id='H2',
                children='Log_SensorCar_USS.csv'),
        html.Br(),
        dbc.Row([
            dbc.Col([speed_max_card], width=2),
            dbc.Col([speed_min_card], width=2),
            dbc.Col([speed_mean_card], width=2),
            dbc.Col([distance_card], width=2),
            dbc.Col([time_sum_card], width=2),
        ], align='center'),
    ]
)

app.layout = html.Div(
    children=[
        html.H1(id='H1',
                children='Übersicht Pi Car',
                style={'textAlign': 'center', 'marginTop': 40, 'marginBottom': 40}),
        html.H1(id='H2',
                children='DasH'),
        html.Div(children='Ein ganz normaler Container (div) für Fließende Objekte'),
        #dcc.Dropdown(id='dropdown',
                     #options=[
                     #    {'label': 'Geschwindigkeit', 'value': 'Geschwindigkeit'},
                     #    {'label': 'Fahrtrichtung', 'value': 'Fahrtrichtung'},
                     #    {'label': 'Lenkwinkel', 'value': 'Lenkwinkel'},
                     #    {'label': 'Abstand_Hindernis', 'value': 'Abstand_Hindernis'},
                     #],
                     #value='Geschwindigkeit'),
         dcc.Graph(id='line_plot', figure=px.line(
            df, x=df['Zeit'], y=df['Geschwindigkeit'])),
        #dcc.Graph(id='line_plot'),
        html.Br(),
        dbc.Row([
            dbc.Col([speed_max_card]),
            dbc.Col([speed_min_card]),
            dbc.Col([speed_mean_card]),
            dbc.Col([distance_card]),
            dbc.Col([time_sum_card]),
        ], align='center'),
    ]
)


@app.callback(Output(component_id='line_plot', component_property='figure'),
              [Input(component_id='dropdown', component_property='value')])
def graph_update(value_of_input_component):
    print(value_of_input_component)
    fig = px.line(df, x=df["Zeit"], y=df[value_of_input_component])
    return fig


if __name__ == '__main__':
    app.run_server(port=8052)

# %% [markdown]
# ### Dash Stufe 3

# %%
from jupyter_dash import JupyterDash
from dash import dcc
from dash import html
import pandas as pd
import numpy as np
import plotly.express as px
from dash.dependencies import Input, Output
import dash_bootstrap_components as dbc
import datetime

df = pd.read_csv('Log_SensorCar_USS_n.csv')

app = JupyterDash()

speed_max = df['Geschwindigkeit'].max()
speed_min = df['Geschwindigkeit'].min()
speed_mean = df['Geschwindigkeit'].mean()
speed_mean = np.round(speed_mean, decimals = 2)


distance = 0
time = 0
time_sum = 0
df.insert(5,'Gefahrene_Zeit', True)
df.insert(6,'Gefahrene_Distanz', True)

for i in df['Geschwindigkeit']:
    
    if i <= 2:
        df['Gefahrene_Zeit'][i] = 0
    else:
        time_1 = df['Zeit'][i-1]
        time_1 = datetime.datetime.strptime(time_1, '%H:%M:%S.%f')

        time_2 = df['Zeit'][i]
        time_2 = datetime.datetime.strptime(time_2, '%H:%M:%S.%f')

        time = time_2 - time_1
        time = time.total_seconds()
        
    speed = df['Geschwindigkeit'][i]
    distance = distance + (time*speed/1000)
    time_sum = time_sum + (time/1000)
    
    df['Gefahrene_Zeit'][i] = time_sum
    df['Gefahrene_Distanz'][i] = distance

distance = np.round(distance, decimals = 2)
time_sum = np.round(time_sum, decimals = 2)

app = JupyterDash(external_stylesheets=[dbc.themes.BOOTSTRAP])


speed_max_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Maximale Geschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_max, body=True),
    ]
)

speed_min_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Minimale Geschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_min, body=True),
    ]
)

speed_mean_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Durchschnittsgeschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_mean, body=True),
        
    ]
)

distance_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Gefahrene Distanz"),
            className="card-text",
        ),
        dbc.Card(distance, body=True),
    ]
)

time_sum_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Gefahrene Zeit"),
            className="card-text",
        ),
        dbc.Card(time_sum, body=True),
    ]
)


app.layout = html.Div(
    children=[
        html.H1(id='H1',
                children='Auswertung des Log-Files',
                style={'textAlign': 'center', 'marginTop': 40, 'marginBottom': 40}),
        html.H1(id='H2',
                children='Log_SensorCar_USS.csv'),
        html.Br(),
        dbc.Row([
            dbc.Col([speed_max_card], width=2),
            dbc.Col([speed_min_card], width=2),
            dbc.Col([speed_mean_card], width=2),
            dbc.Col([distance_card], width=2),
            dbc.Col([time_sum_card], width=2),
        ], align='center'),
    ]
)

app.layout = html.Div(
    children=[
        html.H1(id='H1',
                children='Übersicht Pi Car',
                style={'textAlign': 'center', 'marginTop': 40, 'marginBottom': 40}),
        html.H1(id='H2',
                children='DasH'),
        html.Div(children='Ein ganz normaler Container (div) für Fließende Objekte'),
        dcc.Dropdown(id='dropdown',
                     options=[
                         {'label': 'Geschwindigkeit', 'value': 'Geschwindigkeit'},
                         {'label': 'Fahrtrichtung', 'value': 'Fahrtrichtung'},
                         {'label': 'Lenkwinkel', 'value': 'Lenkwinkel'},
                         {'label': 'Abstand_Hindernis', 'value': 'Abstand_Hindernis'},
                     ],
                     value='Geschwindigkeit'),
        dcc.Graph(id='line_plot'),
        html.Br(),
        dbc.Row([
            dbc.Col([speed_max_card]),
            dbc.Col([speed_min_card]),
            dbc.Col([speed_mean_card]),
            dbc.Col([distance_card]),
            dbc.Col([time_sum_card]),
        ], align='center'),
    ]
)


@app.callback(Output(component_id='line_plot', component_property='figure'),
              [Input(component_id='dropdown', component_property='value')])
def graph_update(value_of_input_component):
    print(value_of_input_component)
    fig = px.line(df, x=df["Zeit"], y=df[value_of_input_component])
    return fig


if __name__ == '__main__':
    app.run_server(port=8052)
# Out:
# <ipython-input-9-3a35dd402731>:30: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-9-3a35dd402731>:45: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# <ipython-input-9-3a35dd402731>:46: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Dash app running on http://127.0.0.1:8052/
# Geschwindigkeit
# Geschwindigkeit
# Geschwindigkeit
# Lenkwinkel
# Abstand_Hindernis
# Geschwindigkeit
