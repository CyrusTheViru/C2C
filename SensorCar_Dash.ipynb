# %% [markdown]
# # Projektphase 1

# %% [markdown]
# ## Lastenheft Aufgabe 10

# %% [markdown]
# ### Dash Stufe 1

# %%
from jupyter_dash import JupyterDash
from dash import dcc
from dash import html
import pandas as pd
import numpy as np
from dash.dependencies import Input, Output
import dash_bootstrap_components as dbc
import datetime

df = pd.read_csv('Log_SensorCar_USS_n.csv')

speed_max = df['Geschwindigkeit'].max()
speed_min = df['Geschwindigkeit'].min()
speed_mean = df['Geschwindigkeit'].mean()
speed_mean = np.round(speed_mean, decimals = 2)

distance = 0
time = 0
time_sum = 0

df.insert(5,'Gefahrene_Zeit', True)
df.insert(6,'Gefahrene_Distanz', True)

for i in df['Geschwindigkeit']:
    if i <= 2:
        df['Gefahrene_Zeit'][i] = 0
    else:
        time_1 = df['Zeit'][i-1]
        time_1 = datetime.datetime.strptime(time_1, '%H:%M:%S.%f')

        time_2 = df['Zeit'][i]
        time_2 = datetime.datetime.strptime(time_2, '%H:%M:%S.%f')

        time = time_2 - time_1
        time = time.total_seconds()
        
    speed = df['Geschwindigkeit'][i]
    distance = distance + (time*speed/1000)
    time_sum = time_sum + (time/1000)
    
    df['Gefahrene_Zeit'][i] = time_sum
    df['Gefahrene_Distanz'][i] = distance

distance = np.round(distance, decimals = 2)
time_sum = np.round(time_sum, decimals = 2)

app = JupyterDash(external_stylesheets=[dbc.themes.BOOTSTRAP])


speed_max_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Maximale Geschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_max, body=True),
    ]
)

speed_min_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Minimale Geschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_min, body=True),
    ]
)

speed_mean_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Durchschnittsgeschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_mean, body=True),
        
    ]
)

distance_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Gefahrene Distanz"),
            className="card-text",
        ),
        dbc.Card(distance, body=True),
    ]
)

time_sum_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Gefahrene Zeit"),
            className="card-text",
        ),
        dbc.Card(time_sum, body=True),
    ]
)


app.layout = html.Div(
    children=[
        html.H1(id='H1',
                children='Auswertung des Log-Files',
                style={'textAlign': 'center', 'marginTop': 40, 'marginBottom': 40}),
        html.H1(id='H2',
                children='Log_SensorCar_USS.csv'),
        html.Br(),
        dbc.Row([
            dbc.Col([speed_max_card], width=2),
            dbc.Col([speed_min_card], width=2),
            dbc.Col([speed_mean_card], width=2),
            dbc.Col([distance_card], width=2),
            dbc.Col([time_sum_card], width=2),
        ], align='center'),
    ]
)

if __name__ == '__main__':
    app.run_server()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:42: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Dash app running on http://127.0.0.1:8050/

# %% [markdown]
# ### Dash Stufe 2

# %%
from jupyter_dash import JupyterDash
from dash import dcc
from dash import html
import pandas as pd
import numpy as np
from dash.dependencies import Input, Output
import dash_bootstrap_components as dbc
import datetime
import plotly.express as px

df = pd.read_csv('Log_SensorCar_USS_n.csv')

speed_max = df['Geschwindigkeit'].max()
speed_min = df['Geschwindigkeit'].min()
speed_mean = df['Geschwindigkeit'].mean()
speed_mean = np.round(speed_mean, decimals = 2)

distance = 0
time = 0
time_sum = 0

df.insert(5,'Gefahrene_Zeit', True)
df.insert(6,'Gefahrene_Distanz', True)

for i in df['Geschwindigkeit']:
    if i <= 2:
        df['Gefahrene_Zeit'][i] = 0
    else:
        time_1 = df['Zeit'][i-1]
        time_1 = datetime.datetime.strptime(time_1, '%H:%M:%S.%f')

        time_2 = df['Zeit'][i]
        time_2 = datetime.datetime.strptime(time_2, '%H:%M:%S.%f')

        time = time_2 - time_1
        time = time.total_seconds()
        
    speed = df['Geschwindigkeit'][i]
    distance = distance + (time*speed/1000)
    time_sum = time_sum + (time/1000)
    
    df['Gefahrene_Zeit'][i] = time_sum
    df['Gefahrene_Distanz'][i] = distance

distance = np.round(distance, decimals = 2)
time_sum = np.round(time_sum, decimals = 2)

app = JupyterDash(external_stylesheets=[dbc.themes.BOOTSTRAP])


speed_max_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Maximale Geschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_max, body=True),
    ]
)

speed_min_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Minimale Geschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_min, body=True),
    ]
)

speed_mean_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Durchschnittsgeschwindigkeit"),
            className="card-text",
        ),
        dbc.Card(speed_mean, body=True),
        
    ]
)

distance_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Gefahrene Distanz"),
            className="card-text",
        ),
        dbc.Card(distance, body=True),
    ]
)

time_sum_card = html.Div(
    [
        dbc.Card(
            dbc.CardBody("Gefahrene Zeit"),
            className="card-text",
        ),
        dbc.Card(time_sum, body=True),
    ]
)

def speed():
    """Function to create a line chart representing the speed over time."""
    fig = px.line(df, x=df['Zeit'], y=df['Geschwindigkeit'])
    return fig


app.layout = html.Div(
    children=[
        html.H1(id='H1',
                children='Auswertung des Log-Files',
                style={'textAlign': 'center', 'marginTop': 40, 'marginBottom': 40}),
        html.H1(id='H2',
                children='Log_SensorCar_USS.csv'),
        html.Br(),
        dbc.Row([
            dbc.Col([speed_max_card], width=2),
            dbc.Col([speed_min_card], width=2),
            dbc.Col([speed_mean_card], width=2),
            dbc.Col([distance_card], width=2),
            dbc.Col([time_sum_card], width=2),
        ], align='center'),
        html.Div(children='Geschwindigkeit'),
        dcc.Graph(id='line_plot', figure=px.line(df, x=df['Zeit'], y=df['Geschwindigkeit'])),
    ]
)

if __name__ == '__main__':
    app.run_server()
# Out:
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:27: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /home/pi/.local/lib/python3.7/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/lib/python3/dist-packages/ipykernel_launcher.py:43: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Dash app running on http://127.0.0.1:8050/
# /home/pi/.local/lib/python3.7/site-packages/jupyter_dash/jupyter_app.py:139: UserWarning:
#
# The 'environ['werkzeug.server.shutdown']' function is deprecated and will be removed in Werkzeug 2.1.

# %% [markdown]
# ### Dash Stufe 3
